# %% [markdown]
# # Lesson 1 - Practice
#
# You read the theory. This lesson is mostly **thinking**, plus a tiny Python warm-up at the end.
#
# Do the exercises in order. Write your answers in the cells.

# %% [markdown]
# ## Warm-up: how to run a cell
# Click the cell below, then press **Shift + Enter**. You should see the message appear under it.

# %%
print("I can run a cell. I am ready to learn.")

# %% [markdown]
# ## Exercise A - Name the ML type
# For each scenario, write **supervised**, **unsupervised**, or **reinforcement**, and one short reason.
# Write your answers as comments in the cell below.

# %%
# A1. A shop has 10,000 past orders labeled "returned" / "kept". Predict new orders.
#    Type:            Reason:
# A2. Group 50,000 songs into similar styles. No labels.
#    Type:            Reason:
# A3. A robot learns to walk by trying and getting reward when it does not fall.
#    Type:            Reason:
# A4. Predict tomorrow's temperature from past weather (we have past temperatures).
#    Type:            Reason:

# %% [markdown]
# ## Exercise B - Regression or Classification?
# Write **regression** (a number) or **classification** (a category).

# %%
# B1. Predict the price of a house.            ->
# B2. Predict if an email is spam or not.       ->
# B3. Predict how many items a shop sells today.->
# B4. Predict if a customer will churn (Yes/No).->

# %% [markdown]
# ## Exercise C - Features and labels
# A bank table has columns: `age`, `salary`, `loan_amount`, and `paid_back` (Yes/No).
# Answer in the cell:

# %%
# C1. Which column is the LABEL (the answer we predict)?  ->
# C2. Name two FEATURES (inputs).                          ->
# C3. Is this supervised or unsupervised? Why?             ->

# %% [markdown]
# ## Assignment - Lesson 1
# **Task 1.** Finish Exercises A, B, C above (all answers filled in).
#
# **Task 2.** In the cell below, write 2-3 sentences: pick ONE real app you use (for example Uzum, Yandex Taxi, a bank app). What do you think it predicts? Is it regression or classification? What features might it use?
#
# **Task 3.** In one sentence: why must we understand the business problem **before** writing code?

# %%
# Task 2 - your answer (2-3 sentences):


# Task 3 - your answer (one sentence):
