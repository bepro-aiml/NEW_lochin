# %% [markdown]
# # Lesson 6 - Practice (Pipelines)
#
# Run each cell. Then do the assignment.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv"
df = pd.read_csv(url)
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
num_cols = ["tenure", "MonthlyCharges", "TotalCharges"]
cat_cols = ["Contract", "PaymentMethod"]
print("ready")

# %% [markdown]
# ## Build the mini-pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

numeric = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),   # fill missing numbers
    ("scaler",  StandardScaler()),                    # scale
])
categorical = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),  # fill missing text
    ("onehot",  OneHotEncoder(handle_unknown="ignore", sparse_output=False)),
])
print("mini-pipelines ready")

# %% [markdown]
# ## Combine with ColumnTransformer

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer([
    ("num", numeric, num_cols),
    ("cat", categorical, cat_cols),
])
print("preprocessor ready - this becomes step 1 of the model in Lesson 7")

# %% [markdown]
# ## Assignment - Lesson 6
# **Task 1 - Comment every line.** Run, then comment every line.

# %%
# TODO: run, then comment every line.
X = df[num_cols + cat_cols]
out = preprocessor.fit_transform(X)
print("shape before:", X.shape)
print("shape after :", out.shape)

# %% [markdown]
# **Task 2 - Answer (one sentence each):**
# 1. In your own words, what does a Pipeline do?
# 2. Does a Pipeline make the model more accurate? (Yes / No and why.)
# 3. What does `joblib.dump(pipeline, "model.joblib")` do?

# %%
# Task 2 - answers:
# 1.
# 2.
# 3.
